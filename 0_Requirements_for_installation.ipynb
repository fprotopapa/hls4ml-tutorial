# %% [markdown]
# # Installation guide for HLS4ML

# %% [markdown]
# Code, files and everything needed is avaible on GitHub under https://github.com/fprotopapa/hls4ml-tutorial.git

# %% [markdown]
# ## Requirements

# %% [markdown]
# ### Operating System

# %% [markdown]
# First, we should be using the Ubuntu operating system.
#
# A guide can be found at the link below.
#
# [How to install Ubuntu 18.04](https://www.linuxtechi.com/ubuntu-18-04-lts-desktop-installation-guide-screenshots/)
#
# This code was tested with version 18.04.
#
# To check your os version, run:

# %%
# %%bash
# cat /etc/lsb-release

# %% [markdown]
# ### Vivado

# %% [markdown]
# Then, we need Xilinx Vivado.
#
# Which is avaible under:
# [Download Vivado](https://www.xilinx.com/support/download/index.html/content/xilinx/en/downloadNav/vivado-design-tools/2019-2.html)
#
# An installation guide for Version 2019.2 can be found [here](https://www.hackster.io/news/vivado-vitis-2019-2-install-on-ubuntu-18-04-lts-93242be6c9eb).
# This is also the version used in this tutorial.
# ```
# Vivado is located at
#
# /tools/Xilinx/Vivado/2019.2/
#
# or sometimes under
#
# /opt/Xilinx/Vivado/2019.2/
#
# this information will be needed later on.
# ```

# %% [markdown]
# ### Python

# %% [markdown]
# Finally, we should be using Python3 and the venv package, these can be installed by running following commands inside the console.
# ```
# sudo apt install python3 python3-venv
# ```
# The version used is 3.6.9.

# %%
# %%bash
# python3 -V

# %% [markdown]
# ### Git

# %% [markdown]
# To use github easily , git can be installed with
# ```
# sudo apt install git
# ```
# Clone this repository with following command

# %%
git clone https://github.com/fprotopapa/hls4ml-tutorial.git

# %% [markdown]
# ### Virtual enviroment and directory structure

# %% [markdown]
# ```
# These steps would be normally done inside the console window.
# ```
# Now let's create a project folder hls4ml and change the working directory.

# %%
# %mkdir hls4ml
# %cd hls4ml

# %% [markdown]
# To keep the system-wide Python installation clean, let's create a virtual enviroment, by running:

# %%
# %%bash
# python3 -m venv venv_hls4ml

# %% [markdown]
# ### Jupter notebook

# %% [markdown]
# To follow along with jupyter notebook, we have to install it.
# This also requires pip, which is the python package-management system.
# The code below will activate the virtual enviroment, install jupyter and add the venv to it.

# %%
# %%bash
# source venv_hls4ml/bin/activate
# pip install --upgrade pip
# pip install jupyterlab
# ipython kernel install --user --name=.venv_hls4ml

# %% [markdown]
# Now to start a jupyter session type
# ```
# jupyter-lab
# ```

# %% [markdown]
# Otherwise just activate the virtual enviroment with
# ```
# source venv_hls4ml/bin/activate
# ```

# %% [markdown]
# ### Now proceed with part 1: 1_Installing_HLS4ML
